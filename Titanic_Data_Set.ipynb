# %% [markdown]
# <a href="https://colab.research.google.com/github/Fuad3004/Data_Science/blob/main/Titanic_Data_Set.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import data

# %%
import pandas as pd

data= "https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/titanic.csv"

df= pd.read_csv(data)
df
# Out:
#       pclass                                             name     sex  \
# 0          1                    Allen, Miss. Elisabeth Walton  female
# 1          1                   Allison, Master. Hudson Trevor    male
# 2          1                     Allison, Miss. Helen Loraine  female
# 3          1             Allison, Mr. Hudson Joshua Creighton    male
# 4          1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...      ...                                              ...     ...
# 1304       3                             Zabour, Miss. Hileni  female
# 1305       3                            Zabour, Miss. Thamine  female
# 1306       3                        Zakarian, Mr. Mapriededer    male
# 1307       3                              Zakarian, Mr. Ortin    male
# 1308       3                               Zimmerman, Mr. Leo    male
#
#           age  sibsp  parch  ticket      fare    cabin embarked  survived
# ...

# %%
df.to_csv("titanic.csv")

# %%
df.to_excel("titanic.xlsx")

# %%
df.describe()
# Out:
#             pclass          age        sibsp        parch         fare  \
# count  1309.000000  1046.000000  1309.000000  1309.000000  1308.000000
# mean      2.294882    29.881135     0.498854     0.385027    33.295479
# std       0.837836    14.413500     1.041658     0.865560    51.758668
# min       1.000000     0.166700     0.000000     0.000000     0.000000
# 25%       2.000000    21.000000     0.000000     0.000000     7.895800
# 50%       3.000000    28.000000     0.000000     0.000000    14.454200
# 75%       3.000000    39.000000     1.000000     0.000000    31.275000
# max       3.000000    80.000000     8.000000     9.000000   512.329200
#
#           survived
# count  1309.000000
# mean      0.381971
# std       0.486055
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       1.000000
# max       1.000000

# %% [markdown]
# df.iloc[row_index, column_index]

# %%
df.iloc[0,0:2]
# Out:
# pclass                                1
# name      Allen, Miss. Elisabeth Walton
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# pclass                                  1
# name        Allen, Miss. Elisabeth Walton
# sex                                female
# age                                  29.0
# sibsp                                   0
# parch                                   0
# ticket                              24160
# fare                             211.3375
# cabin                                  B5
# embarked                                S
# survived                                1
# Name: 0, dtype: object

# %%
# multi column


df.loc[:,["name", "sex"]]
# Out:
#                                                  name     sex
# 0                       Allen, Miss. Elisabeth Walton  female
# 1                      Allison, Master. Hudson Trevor    male
# 2                        Allison, Miss. Helen Loraine  female
# 3                Allison, Mr. Hudson Joshua Creighton    male
# 4     Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
# ...                                               ...     ...
# 1304                             Zabour, Miss. Hileni  female
# 1305                            Zabour, Miss. Thamine  female
# 1306                        Zakarian, Mr. Mapriededer    male
# 1307                              Zakarian, Mr. Ortin    male
# 1308                               Zimmerman, Mr. Leo    male
#
# [1309 rows x 2 columns]

# %%
from matplotlib import pyplot as plt
import seaborn as sns
_df_18.groupby('sex').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df['sex'].describe()
# Out:
# count     1309
# unique       2
# top       male
# freq       843
# Name: sex, dtype: object

# %%
df['pclass'].unique()
# Out:
# array([1, 2, 3])

# %%
df[["fare","age"]].mean()
# Out:
# fare    33.295479
# age     29.881135
# dtype: float64

# %%
df[["fare","age"]].mean(axis=1)
# Out:
# 0       120.16875
# 1        76.23335
# 2        76.77500
# 3        90.77500
# 4        88.27500
#           ...
# 1304     14.47710
# 1305     14.45420
# 1306     16.86250
# 1307     17.11250
# 1308     18.43750
# Length: 1309, dtype: float64

# %%
df.mean(numeric_only=True)
# Out:
# pclass       2.294882
# age         29.881135
# sibsp        0.498854
# parch        0.385027
# fare        33.295479
# survived     0.381971
# dtype: float64
