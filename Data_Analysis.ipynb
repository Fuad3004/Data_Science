# %% [markdown]
# <a href="https://colab.research.google.com/github/Fuad3004/Data_Science/blob/main/Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q xlrd
import pandas as pd
retail = pd.read_excel('/content/retail_sales_data.xlsx')
retail.to_csv('retailsales.csv', index=False)

# %%
df=pd.read_csv('/content/retailsales.csv')

# %%
df
# Out:
#        InvoiceNo StockCode                       Description  Quantity  \
# 0         536367     22622    BOX OF VINTAGE ALPHABET BLOCKS         2
# 1         536372     22633            HAND WARMER UNION JACK         6
# 2         536375     22752      SET 7 BABUSHKA NESTING BOXES         2
# 3         536381     84832  ZINC WILLIE WINKIE  CANDLE STICK         1
# 4         536382     21832              CHOCOLATE CALCULATOR        12
# ...          ...       ...                               ...       ...
# 12441     581578     21497         FANCY FONTS BIRTHDAY WRAP        25
# 12442     581578      POST                           POSTAGE         3
# 12443     581579     23318    BOX OF 6 MINI VINTAGE CRACKERS        12
# 12444     581582     23498             CLASSIC BICYCLE CLIPS        12
# 12445     581587     22613       PACK OF 20 SPACEBOY NAPKINS        12
#
#       InvoiceDate  UnitPrice  Profit  CustomerID         Country
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12446, step=1)

# %%
df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'Profit', 'CustomerID', 'Country'],
#       dtype='object')

# %%
df['InvoiceNo']
# Out:
# 0        536367
# 1        536372
# 2        536375
# 3        536381
# 4        536382
#           ...
# 12441    581578
# 12442    581578
# 12443    581579
# 12444    581582
# 12445    581587
# Name: InvoiceNo, Length: 12446, dtype: int64

# %%
df.InvoiceNo
# Out:
# 0        536367
# 1        536372
# 2        536375
# 3        536381
# 4        536382
#           ...
# 12441    581578
# 12442    581578
# 12443    581579
# 12444    581582
# 12445    581587
# Name: InvoiceNo, Length: 12446, dtype: int64

# %%
#.loc() accessor method

# %%
df.loc[0]
# Out:
# InvoiceNo                              536367
# StockCode                               22622
# Description    BOX OF VINTAGE ALPHABET BLOCKS
# Quantity                                    2
# InvoiceDate                        2018-12-01
# UnitPrice                                9.95
# Profit                                   4.68
# CustomerID                              13047
# Country                        United Kingdom
# Name: 0, dtype: object

# %%
type(df.loc[1])
# Out:
# pandas.core.series.Series

# %%
#df.loc[row label,column label]

df.loc[[0,1,2],['InvoiceNo', 'Profit']]
# Out:
#    InvoiceNo  Profit
# 0     536367    4.68
# 1     536372    1.13
# 2     536375    2.83

# %%
df.loc[[0,1,2],:]
# Out:
#    InvoiceNo StockCode                     Description  Quantity InvoiceDate  \
# 0     536367     22622  BOX OF VINTAGE ALPHABET BLOCKS         2  2018-12-01
# 1     536372     22633          HAND WARMER UNION JACK         6  2018-12-01
# 2     536375     22752    SET 7 BABUSHKA NESTING BOXES         2  2018-12-01
#
#    UnitPrice  Profit  CustomerID         Country
# 0       9.95    4.68       13047  United Kingdom
# 1       1.85    1.13       17850  United Kingdom
# 2       7.65    2.83       17850  United Kingdom

# %%
df.loc[df['Profit'].idxmax()]
# Out:
# InvoiceNo          552980
# StockCode            POST
# Description       POSTAGE
# Quantity                1
# InvoiceDate    2019-05-12
# UnitPrice           523.0
# Profit              83.68
# CustomerID          12590
# Country           Germany
# Name: 4019, dtype: object

# %%
# find the top 5 maximum profit

df.loc[df['Profit'].nlargest(5).index]
# Out:
#        InvoiceNo StockCode                    Description  Quantity  \
# 4019      552980      POST                        POSTAGE         1
# 10439     575494     22826  LOVE SEAT ANTIQUE WHITE METAL         3
# 5589      559458     22826  LOVE SEAT ANTIQUE WHITE METAL         1
# 7520      566557     22823  CHEST NATURAL WOOD 20 DRAWERS         2
# 410       538002        C2                       CARRIAGE         1
#
#       InvoiceDate  UnitPrice  Profit  CustomerID          Country
# 4019   2019-05-12      523.0   83.68       12590          Germany
# 10439  2019-11-10       85.0   59.50       17500   United Kingdom
# 5589   2019-07-08       85.0   58.65       14104   United Kingdom
# 7520   2019-09-13      110.0   44.00       14646      Netherlands
# 410    2018-12-09       50.0   36.50       14932  Channel Islands

# %%
#iloc accessor method

#df.iloc[integer indexes of rows, integer indexes for columns]


df.iloc[0, [0,1]]
# Out:
# InvoiceNo    536367
# StockCode     22622
# Name: 0, dtype: object

# %%
df.iloc[0,:]
# Out:
# InvoiceNo                              536367
# StockCode                               22622
# Description    BOX OF VINTAGE ALPHABET BLOCKS
# Quantity                                    2
# InvoiceDate                        2018-12-01
# UnitPrice                                9.95
# Profit                                   4.68
# CustomerID                              13047
# Country                        United Kingdom
# Name: 0, dtype: object

# %%
df.iloc[0:5, 0:3]
# Out:
#    InvoiceNo StockCode                       Description
# 0     536367     22622    BOX OF VINTAGE ALPHABET BLOCKS
# 1     536372     22633            HAND WARMER UNION JACK
# 2     536375     22752      SET 7 BABUSHKA NESTING BOXES
# 3     536381     84832  ZINC WILLIE WINKIE  CANDLE STICK
# 4     536382     21832              CHOCOLATE CALCULATOR

# %%
df.iat[5,5]
# Out:
# 1.65

# %% [markdown]
# #modifying DataFrame Values

# %%
df.loc[:4, 'StockCode']=[12121,23213,324545134,32123,12121]
df
# Out:
#        InvoiceNo  StockCode                       Description  Quantity  \
# 0         536367      12121    BOX OF VINTAGE ALPHABET BLOCKS         2
# 1         536372      23213            HAND WARMER UNION JACK         6
# 2         536375  324545134      SET 7 BABUSHKA NESTING BOXES         2
# 3         536381      32123  ZINC WILLIE WINKIE  CANDLE STICK         1
# 4         536382      12121              CHOCOLATE CALCULATOR        12
# ...          ...        ...                               ...       ...
# 12441     581578      21497         FANCY FONTS BIRTHDAY WRAP        25
# 12442     581578       POST                           POSTAGE         3
# 12443     581579      23318    BOX OF 6 MINI VINTAGE CRACKERS        12
# 12444     581582      23498             CLASSIC BICYCLE CLIPS        12
# 12445     581587      22613       PACK OF 20 SPACEBOY NAPKINS        12
#
#       InvoiceDate  UnitPrice  Profit  CustomerID         Country
# ...
