# %% [markdown]
# <a href="https://colab.research.google.com/github/Fuad3004/Data_Science/blob/main/Data_Analysis_with_Python_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
'Math Score': [85, 92, 78, 88],
'English Score': [90, 86, 92, 80]}

df = pd.DataFrame(data)
df
# Out:
#       Name  Math Score  English Score
# 0    Alice          85             90
# 1      Bob          92             86
# 2  Charlie          78             92
# 3    David          88             80

# %%
#1 Retrieve the English score of 'Charlie'.

df.loc[[2],['Name','English Score']]
# Out:
#       Name  English Score
# 2  Charlie             92

# %%
#2 Get the Math scores of all students.

df.iloc[:,1]
# Out:
# 0    85
# 1    92
# 2    78
# 3    88
# Name: Math Score, dtype: int64

# %%
#3 Access the English score of the first student.
df.loc[[0],['Name','English Score']]
# Out:
#     Name  English Score
# 0  Alice             90

# %%
#4 Retrieve the Math score of the last student.
df.loc[[3],['Name','Math Score']]
# Out:
#     Name  Math Score
# 3  David          88

# %%
#5 Update Bob's Math score to 95.
df.loc[1,'Math Score']=[95]
df
# Out:
#       Name  Math Score  English Score
# 0    Alice          85             90
# 1      Bob          95             86
# 2  Charlie          78             92
# 3    David          88             80

# %%
#6 Increase Charlie's English score by 5 points.

df.loc[df['Name'] == 'Charlie', 'English Score'] = df['English Score'] + 5
df
# Out:
#       Name  Math Score  English Score
# 0    Alice          85             90
# 1      Bob          95             86
# 2  Charlie          78             97
# 3    David          88             80

# %%
#7 Add a new row for 'Eve' with Math Score 88 and English Score 95.
df.loc[4]=['Eve','88','95']
df
# Out:
#       Name Math Score English Score
# 0    Alice         85            90
# 1      Bob         95            86
# 2  Charlie         78            97
# 3    David         88            80
# 4      Eve         88            95

# %%
#8 Delete the row for 'David' from the DataFrame.
df.drop(labels=[3],inplace=True)
df.reset_index(inplace=True)
del df['index']
df
# Out:
#       Name Math Score English Score
# 0    Alice         85            90
# 1      Bob         95            86
# 2  Charlie         78            97
# 3      Eve         88            95

# %%
#9 Insert a new column called 'Science Score' with values .
df.insert(loc=3, column='Science Score', value=[92, 84, 89, 78])
df
# Out:
#       Name Math Score English Score  Science Score
# 0    Alice         85            90             92
# 1      Bob         95            86             84
# 2  Charlie         78            97             89
# 3      Eve         88            95             78

# %%
#10 Delete the 'English Score' column from the DataFrame.
n= df.drop(labels=['English Score'],axis=1,inplace=False)
n
# Out:
#       Name Math Score  Science Score
# 0    Alice         85             92
# 1      Bob         95             84
# 2  Charlie         78             89
# 3      Eve         88             78

# %%
#11 Create a new column 'Total Score' that represents the sum of Math Score and English Score for each student.
data = {'Name': ['Alice', 'Bob', 'Charlie', 'David'],
'Math Score': [85, 92, 78, 88],
'English Score': [90, 86, 92, 80]}

df = pd.DataFrame(data)

df= df.astype(dtype={'Math Score':np.float64, 'English Score':np.float64})
df['Total Score']=df['Math Score']+ df['English Score']
df
# Out:
#       Name  Math Score  English Score  Total Score
# 0    Alice        85.0           90.0        175.0
# 1      Bob        92.0           86.0        178.0
# 2  Charlie        78.0           92.0        170.0
# 3    David        88.0           80.0        168.0

# %%
#12 Find the student with the highest Total Score.
max_score = df['Total Score'].max()
max_score_student = df[df['Total Score'] == max_score]

max_score_student
# Out:
#   Name  Math Score  English Score  Total Score
# 1  Bob        92.0           86.0        178.0

# %% [markdown]
# Q. Combine this DataFrame (df2) with the original DataFrame (df) to create a new DataFrame that includes all students.

# %%
data2 = {'Name': ['Eve', 'Frank'],
'Math Score': [87, 76],
'English Score': [94, 82]}
df2 = pd.DataFrame(data2)

df2
# Out:
#     Name  Math Score  English Score
# 0    Eve          87             94
# 1  Frank          76             82

# %%
df = pd.concat([df, df2], axis=0)
df.reset_index(inplace=True)
del df['index']
df= df.astype(dtype={'Math Score':np.float64, 'English Score':np.float64})
df['Total Score']=df['Math Score']+ df['English Score']
df
# Out:
#       Name  Math Score  English Score  Total Score
# 0    Alice        85.0           90.0        175.0
# 1      Bob        92.0           86.0        178.0
# 2  Charlie        78.0           92.0        170.0
# 3    David        88.0           80.0        168.0
# 4      Eve        87.0           94.0        181.0
# 5    Frank        76.0           82.0        158.0
